# %% [markdown]
# # PANDAS
#
# - Basically used for data analysis.
# - Built of top of numpy only.
# - Going to be heavily used.
# - data manipulation, visualisation , building ML models
#
# ## Main Data Structure of Pandas
#
# - Series (like 1-D array/Numpy array like)
# - Dataframe(default one when we will discussing)
#
# - Table representation can be like dataframe.
# - For particular column can denoted like series.
#
# - Eg. in fig:
# ![image.png](attachment:image.png)

# %% [markdown]
# #  Creating Pandas Series

# %%
import pandas as pd

# %%
a = pd.Series([1,2,3,4,5]) # this is homogeneous in nature

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#same thing like before

a[2]
# Out:
# 3

# %%
a = pd.Series(['a','b','c'])

# %%
a #in pandas series string/char represented as object
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
# if we need sth like range in python , np.arange in numpy then
# if we want to retrieve particular date from data then
 
a = pd.date_range(start = '01-01-2018',end='23-5-2018')

# %%
a
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2018-05-14', '2018-05-15', '2018-05-16', '2018-05-17',
#                '2018-05-18', '2018-05-19', '2018-05-20', '2018-05-21',
#                '2018-05-22', '2018-05-23'],
#               dtype='datetime64[ns]', length=143, freq='D')

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# # Pandas Dataframe
#
# - Dataframe is like table which contains rows and columns
# - row can have a index and column can have meaningful names.
# - Different ways of creating dataframe:
